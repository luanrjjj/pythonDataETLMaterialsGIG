# %%
from openpyxl import *
import pandas as pd
import openpyxl as xl
import xlrd
import shutil
import os 



sheet_name=["PISTAS","LIMPEZA","Mecânica","MAN.TECA","ELETRICA","PPC","AIRSIDE","EMERGENCIA","SEG.TECA","TERMINAL","SUSTENT."]
    

for centroDeCusto in sheet_name:
    wb = pd.read_excel(r'C:\Users\Luan\Desktop\python\Insumos e Materiais_2021.xlsx',centroDeCusto,header = 7)
    wbnew=wb.rename(columns = {"Custo Janeiro Orçado" :"Custo Orçado","Quantidade Janeiro Orçada":"Quantidade Orçada","Status Janeiro":"Status","Justificativa Janeiro":"Justificativa",
                           "Custo Janeiro Realizado":"Custo Realizado","Quantidade Janeiro Realizada":"Quantidade Realizada",
                               
                           "Custo Fevereiro Orçado": "Custo Orçado","Quantidade Fevereiro Orçada":"Quantidade Orçada",
                            "Custo Fevereiro Realizado":"Custo Realizado","Quantidade Fevereiro Realizada":"Quantidade Realizada",
                            "Status Fevereiro":"Status","Justificativa Fevereiro": "Justificativa",
                               
                               
                            "Custo Março Orçado":"Custo Orçado","Quantidade Março Orçada":"Quantidade Orçada",
                            "Custo Março Realizado":"Custo Realizado","Quantidade Março Realizada":"Quantidade Realizada",
                            "Status Março":"Status","Justificativa Março":"Justificativa",
                               
                            "Custo Abril Orçado":"Custo Orçado","Quantidade Abril Orçada":"Quantidade Orçada","Custo Abril Realizado":"Custo Realizado",
                            "Quantidade Abril Realizada":"Quantidade Realizada","Status Abril":"Status","Justificativa Abril":"Justificativa",
                                                                                                                                                                               
                            "Custo Maio Orçado":"Custo Orçado","Quantidade Maio Orçada":"Quantidade Orçada","Custo Maio Realizado":
                            "Custo Realizado","Quantidade Maio Realizada":"Quantidade Realizada","Justificativa Maio":"Justificativa",
                            "Status Maio":"Status",
                               
                            "Custo Junho Orçado":"Custo Orçado","Quantidade Junho Orçada":"Quantidade Orçada","Custo Junho Realizado":"Custo Realizado",
                            "Quantidade Junho Realizada":"Quantidade Realizada","Status Junho":"Status","Justificativa Junho":"Justificativa",
                               
                            "Custo Julho Orçado":"Custo Orçado","Quantidade Julho Orçada":"Quantidade Orçada","Custo Julho Realizado":"Custo Realizado",
                            "Quantidade Julho Realizada":"Quantidade Realizada","Status Julho":"Status","Justificativa Julho":"Justificativa",
                               
                            
                           "Quantidade Setembro Orçada":"Quantidade Orçada","Custo Setembro Orçado":"Custo Orçado",
                           "Custo Setembro Realizado":"Custo Realizado","Quantidade Setembro Realizada":"Quantidade Realizada",
                           "Status Setembro":"Status","Justificativa Setembro":"Justificativa",
                           
                           "Quantidade Agosto Orçada":"Quantidade Orçada","Custo Agosto Orçado":"Custo Orçado","Justificativa Agosto":"Justificativa","Status Agosto":"Status",
                           "Custo Agosto Realizado":"Custo Realizado","Quantidade Agosto Realizado":"Quantidade Realizada",
                           
                               
                           "Quantidade Outubro Orçada":"Quantidade Orçada","Custo Outubro Orçado":"Custo Orçado",
                           "Custo Outubro Realizado":"Custo Realizado",
                           "Quantidade Outubro Realizada": "Quantidade Realizada","Status Outubro":"Status",
                           "Justificativa Outubro":"Justificativa",
                            
                           "Quantidade Novembro Orçado":"Quantidade Orçada",
                           "Custo Novembro Orçado":"Custo Orçado","Quantidade Novembro Realizado":"Quantidade Realizada",
                           "Custo Novembro Realizado":"Custo Realizado","Justificativa Novembro":"Justificativa",
                           "Status Novembro":"Status",
                               
                           "Quantidade Orçada Dezembro":"Quantidade Orçada",
                           "Custo Dezembro Orçado":"Custo Orçado","Quantidade Dezembro Realizada":"Quantidade Realizada",
                           "Custo Dezembro Realizado":"Custo Realizado","Status Dezembro":"Status",
                           "Justificativa Dezembro":"Justificativa"})
    
    
                                  ############## FATIAMENTO DA PLANILHA de Materiais ############
    wb1 = wbnew.iloc[:,0:13] 
    wb1=wb1.assign(Mês = lambda x :"01/2020" )

    index = wb1.index

    wb2 = wbnew.iloc[:,13:19] 
    wb2 = wb2.assign(Mês = lambda x :"02/2020")
    
    wb3 = wbnew.iloc[:,19:25] 
    wb3 = wb3.assign(Mês = lambda x :"03/2020")
    
    wb4 = wbnew.iloc[:,25:31] 
    wb4 = wb4.assign(Mês = lambda x :"04/2020")
    
    wb5 = wbnew.iloc[:,31:37] 
    wb5 = wb5.assign(Mês = lambda x :"05/2020")
    
    wb6 = wbnew.iloc[:,37:43] 
    wb6 = wb6.assign(Mês = lambda x :"06/2020")
    
    wb7 = wbnew.iloc[:,43:49] 
    wb7 = wb7.assign(Mês = lambda x :"07/2020")

    wb8 = wbnew.iloc[:,49:55] 
    wb8 = wb8.assign(Mês = lambda x :"08/2020")

    wb9 = wbnew.iloc[:,55:61] 
    wb9 = wb9.assign(Mês = lambda x :"09/2020" )

    wb10 = wbnew.iloc[:,61:67] 
    wb10 = wb10.assign(Mês = lambda x :"10/2020")

    wb11 = wbnew.iloc[:,67:73] 
    wb11 = wb11.assign(Mês = lambda x :"11/2020")

    wb12 = wbnew.iloc[:,73:79] 
    wb12 = wb12.assign(Mês = lambda x :"12/2020")

    frames = [wb1,wb2,wb3,wb4,wb5,wb6,wb7,wb8,wb9,wb10,wb11,wb12]

    wb13 = pd.concat(frames,keys=[ 's1','s2','s3','s4','s5','s6','s7','s8','s9','s10','s11','s12'],sort = False,copy=False)
                       
    wb13 = wb13.assign(CC = lambda x:centroDeCusto)
    

    
    
    
    
    location0= r'C:\Users\Luan\Desktop\python\tratamento.xlsx'
    name =location0.split('.')[0]
    
    location = f'{name}{centroDeCusto}.xlsx'

    wb13.to_excel(location)

                                   ####### Copia entre Arquivos ###


    
    destination = f'{name}{centroDeCusto}updated.xlsx'
    
    shutil.copy(location,destination)

    index = wb1.index
    rows_count =len(index)
    columns_count = 8
    sheet = wb13
    startCol=3
    
    

    src_ws = xl.load_workbook(location) #Add file name
    src_s = src_ws["Sheet1"]

    dst_ws = xl.load_workbook(destination)
    dst_s = dst_ws["Sheet1"]



    def copyRange(startCol, startRow, endCol, endRow, sheet):
        rangeSelected = []
        #Loops through selected Rows
        for i in range(startRow,endRow + 2,1):
            #Appends the row to a RowSelected list
            rowSelected = []
            for j in range(startCol,endCol+1,1):
                rowSelected.append(sheet.cell(row = i, column = j).value)
            #Adds the RowSelected List and nests inside the rangeSelected
            rangeSelected.append(rowSelected)

        return rangeSelected

    
    #### Essa seção copia os dados
        
    def pasteRange(startCol, startRow, endCol, endRow, sheetReceiving,copiedData):
        countRow = 0
        for i in range(startRow,endRow,1):
            countCol = 0
            for j in range(startCol,endCol+1,1):
                if countCol <6:
                    sheetReceiving.cell(row = i, column = j).value = copiedData[countRow][countCol]
                    countCol += 1
            countRow += 1


    def createData(n):
        print("Processing...")
        selectedRange = copyRange(3,2,columns_count,rows_count,src_s)
        print("selectedRange")
        pastingRange = pasteRange(3,rows_count*(n-1)+2,columns_count,rows_count*n+2,dst_s,selectedRange)
        print("pastingRange")
        dst_ws.save(destination)
        print("Range copied and pasted!")
        
        
    n=2
    while n <  13:
        print(centroDeCusto)
        print(rows_count)
        print(n)
        go = createData(n)
        n+=1
# Out:
# PISTAS
# 992
# 2
# Processing...
# selectedRange
# pastingRange
# Range copied and pasted!
# PISTAS
# 992
# 3
# Processing...
# selectedRange
# pastingRange
# Range copied and pasted!
# PISTAS
# 992
# 4
# Processing...
# selectedRange
# pastingRange
# Range copied and pasted!
# PISTAS
# 992
# 5
# Processing...
# selectedRange
# pastingRange
# Range copied and pasted!
# PISTAS
# 992
# 6
# Processing...
# selectedRange
# pastingRange
# Range copied and pasted!
# PISTAS
# 992
# 7
# Processing...
# selectedRange
# pastingRange
# Range copied and pasted!
# PISTAS
# 992
# 8
# Processing...
# selectedRange
# pastingRange
# Range copied and pasted!
# PISTAS
# 992
# 9
# Processing...
# selectedRange
# pastingRange
# Range copied and pasted!
# PISTAS
# 992
# 10
# Processing...
# selectedRange
# pastingRange
# Range copied and pasted!
# PISTAS
# 992
# 11
# Processing...
# selectedRange
# pastingRange
# Range copied and pasted!
# PISTAS
# 992
# 12
# Processing...
# selectedRange
# pastingRange
# ...

# %%
import glob
all_data = pd.DataFrame()

for f in glob.glob(r'C:\Users\Luan\Desktop\python\*updated.xlsx'):
    df=pd.read_excel(f)
    all_data = all_data.append(df,ignore_index=True)
all_data.to_excel(r'C:\Users\Luan\Desktop\python\testeCompilado.xlsx')
# Out:
# C:\Users\Luan\Anaconda3\lib\site-packages\pandas\core\frame.py:6211: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   sort=sort)

# %%
from IPython.display import display
tt = pd.read_excel(r'C:\Users\Luan\Desktop\python\testeCompilado.xlsx')
pd.options.display.max_columns = None

# %%
fnames = {'Orçado e Realizado': 1}
gnames = {'Orçado e Não Realizado': 1}
hnames = {'Realizado e Não Orçado':1}

tt['orcRealizadoo'] = tt['Status'].map(fnames)
tt['orcNaoRealizadoo'] = tt['Status'].map(gnames)
tt['realizadoNaoOrcado'] = tt['Status'].map(hnames)

# %%
display(tt)
# Out:
#                  Ativo        CC  Custo Orçado Custo Realizado Código SAP  \
# 0       UNIFORME / EPI   AIRSIDE       6207.32               0        NaN
# 1       UNIFORME / EPI   AIRSIDE        117.81               0        NaN
# 2       UNIFORME / EPI   AIRSIDE         42.00              42        NaN
# 3       UNIFORME / EPI   AIRSIDE        137.04          137.04        NaN
# 4       UNIFORME / EPI   AIRSIDE        191.94               0        NaN
# 5       UNIFORME / EPI   AIRSIDE        639.80               0        NaN
# 6       UNIFORME / EPI   AIRSIDE       2256.00               0        NaN
# 7       UNIFORME / EPI   AIRSIDE        895.72               0        NaN
# 8       UNIFORME / EPI   AIRSIDE        447.86               0        NaN
# 9       UNIFORME / EPI   AIRSIDE        255.92               0        NaN
# 10      UNIFORME / EPI   AIRSIDE        269.70               0        NaN
# 11      UNIFORME / EPI   AIRSIDE        179.80               0        NaN
# ...

# %%
tt.to_excel(r'C:\Users\Luan\Desktop\python\testeCompilado1.xlsx')
